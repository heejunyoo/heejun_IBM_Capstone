# %% [markdown]
# # 1. Table from web as Data Frame

# %% [markdown]
# ### Import Packages
# I am going to utilize BeautifulSoup, request as web table scraping tool

# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import urllib.request
import re

# %% [markdown]
# ### Web Scraping

# %%
source = urllib.request.urlopen('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').read()
soup = bs(source, 'lxml')

# %% [markdown]
# ### Using 'find, find_all' from BeautifulSoup to get rows and columns

# %%
table = soup.table
table = soup.find('table')
table_rows = table.find_all('tr')

df_table = []

for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    df_table.append(row)

# %% [markdown]
# ### list into Data Frame and merge into one column

# %%
# set column names
df = pd.DataFrame(df_table, columns=['1', '2', '3', '4', '5', '6', '7', '8', '9'])

# replace '\n' string into ''
df = df.replace('\n','', regex=True)

# merge all column values into one column
df_concat = pd.concat([df, df.unstack().reset_index(drop=True).rename('10')], axis=1)

# %% [markdown]
# ### split value by character length, and ignoring 'Not assigned' value

# %%
# Splitting value by character length into 2 columns
df_concat['PostalCode'] = df_concat['10'].str[:3].replace('\n','', regex=True)
df_concat['BN'] = df_concat['10'].str[3:]

# Select 2 columns only for easy preprocessing
dfs = df_concat[['PostalCode', 'BN']]

# Ignoring specific string value
dfs = dfs[~(dfs['BN'] == "Not assigned")]

# %% [markdown]
# ### split value by special character, and replace special character to others

# %%
# split value by spacieal character - first column
dfs['Borough'] = dfs['BN'].str.split('\(', expand=True)[0]

# split value by special character - second column, replace special character to other
dfs['Neighborhood'] = dfs['BN'].str.split('\(', expand=True)[1].replace(' /', ',', regex=True).replace('\)', '', regex=True)

# choose 3 columns as new Data Frame
dfs = dfs[['PostalCode', 'Borough', 'Neighborhood']]

# %%
# dfs[dfs['Neighborhood'].isna()]

dfs[dfs['Borough'].str.contains('Queen') == True]

# None
# Enclave of L4W
# Enclave of M4L
# Out:
#     PostalCode                                       Borough Neighborhood
# 120        M7A  Queen's Park / Ontario Provincial Government         None

# %% [markdown]
# ## Result

# %%
dfs.head(12)
# Out:
#    PostalCode      Borough                                       Neighborhood
# 1         M1B  Scarborough                                     Malvern, Rouge
# 2         M1C  Scarborough             Rouge Hill, Port Union, Highland Creek
# 3         M1E  Scarborough                  Guildwood, Morningside, West Hill
# 4         M1G  Scarborough                                             Woburn
# 5         M1H  Scarborough                                          Cedarbrae
# 6         M1J  Scarborough                                Scarborough Village
# 7         M1K  Scarborough        Kennedy Park, Ionview, East Birchmount Park
# 8         M1L  Scarborough                    Golden Mile, Clairlea, Oakridge
# 9         M1M  Scarborough    Cliffside, Cliffcrest, Scarborough Village West
# 10        M1N  Scarborough                        Birch Cliff, Cliffside West
# 11        M1P  Scarborough  Dorset Park, Wexford Heights, Scarborough Town...
# 12        M1R  Scarborough                                  Wexford, Maryvale

# %%
dfs.shape
# Out:
# (103, 3)

# %% [markdown]
# # 2. Get the geographical coordinates of each postal code

# %% [markdown]
# ### read csv from the url link

# %%
geo_df = pd.read_csv('http://cocl.us/Geospatial_data')

# %%
print(geo_df.shape)
geo_df.head()
# Out:
# (103, 3)
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ### Merge two DataFrame into one DataFrame, 'Postal Code' as the Key value

# %%
dfs_geo = pd.merge(dfs, geo_df, how='left', left_on='PostalCode', right_on='Postal Code').drop(['Postal Code'], axis=1)

# %% [markdown]
# ## Result

# %%
dfs_geo.head(12)
# Out:
#    PostalCode      Borough                                       Neighborhood  \
# 0         M1B  Scarborough                                     Malvern, Rouge
# 1         M1C  Scarborough             Rouge Hill, Port Union, Highland Creek
# 2         M1E  Scarborough                  Guildwood, Morningside, West Hill
# 3         M1G  Scarborough                                             Woburn
# 4         M1H  Scarborough                                          Cedarbrae
# 5         M1J  Scarborough                                Scarborough Village
# 6         M1K  Scarborough        Kennedy Park, Ionview, East Birchmount Park
# 7         M1L  Scarborough                    Golden Mile, Clairlea, Oakridge
# 8         M1M  Scarborough    Cliffside, Cliffcrest, Scarborough Village West
# 9         M1N  Scarborough                        Birch Cliff, Cliffside West
# 10        M1P  Scarborough  Dorset Park, Wexford Heights, Scarborough Town...
# 11        M1R  Scarborough                                  Wexford, Maryvale
#
#      Latitude  Longitude
# 0   43.806686 -79.194353
# 1   43.784535 -79.160497
# 2   43.763573 -79.188711
# 3   43.770992 -79.216917
# 4   43.773136 -79.239476
# 5   43.744734 -79.239476
# 6   43.727929 -79.262029
# 7   43.711112 -79.284577
# 8   43.716316 -79.239476
# 9   43.692657 -79.264848
# 10  43.757410 -79.273304
# 11  43.750072 -79.295849

# %%
dfs_geo.shape
# Out:
# (103, 5)

# %% [markdown]
# # 3. Segmenting and Clustering Neighborhoods in Toronto

# %%
import json
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import numpy as np

# !conda install -c conda-forge folium=0.5.0 --yes
import folium
print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Understand about dataset - how many boroughs and neighborhods?

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(dfs_geo['Borough'].unique()),
        dfs_geo.shape[0]
    )
)
# Out:
# The dataframe has 15 boroughs and 103 neighborhoods.

# %% [markdown]
# ### Get the geolocation of Toronto

# %%
address = 'Toronto, ON, Canada'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %% [markdown]
# ### Visualize neighborhood into toronto folium map

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, borough, neighborhood in zip(dfs_geo['Latitude'], dfs_geo['Longitude'], dfs_geo['Borough'], dfs_geo['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Set variable of Foursquare Credential

# %%
# @hidden_cell
CLIENT_ID = 'Z3YXZ4HYRYM2K4YNBYBCRAD01CAOLNLOSYB2JK3SNGLGYJ3N'# Foursquare ID
# Z3YXZ4HYRYM2K4YNBYBCRAD01CAOLNLOSYB2JK3SNGLGYJ3N # google
# AQYAOEFJFWC12AHJDJ1U05SKTTMUOTNG2BYYTFGKIDSDUTUN # icloud
CLIENT_SECRET = 'JYSUOFMK0K3IY5XH4BD5KTXK344D1PVDOILL0MUWZCKZABK5' # Foursquare Secret
# JYSUOFMK0K3IY5XH4BD5KTXK344D1PVDOILL0MUWZCKZABK5 # google
# UUQSDTYH1J2TFESOEB4LWNJBSLTG1PNRIOCZ0W5FJRALMBF1 # icloud
VERSION = '20180605' # Foursquare API version

print('Credentails')
# Out:
# Credentails

# %% [markdown]
# ### Generate python function
# * empty list to store data
# * API request with credential above
# * GET request
# * from the result, extract required data and store into emyty list
# * modify list into Data Frame, and set the column name

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ### apply above function into all Neighborhood data

# %%
venues = getNearbyVenues(names=dfs_geo['Neighborhood'],
                                   latitudes=dfs_geo['Latitude'],
                                   longitudes=dfs_geo['Longitude']
                        )
# Out:
# Malvern, Rouge
# Rouge Hill, Port Union, Highland Creek
# Guildwood, Morningside, West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# Kennedy Park, Ionview, East Birchmount Park
# Golden Mile, Clairlea, Oakridge
# Cliffside, Cliffcrest, Scarborough Village West
# Birch Cliff, Cliffside West
# Dorset Park, Wexford Heights, Scarborough Town Centre
# Wexford, Maryvale
# Agincourt
# Clarks Corners, Tam O'Shanter, Sullivan
# Milliken, Agincourt North, Steeles East, L'Amoreaux East
# Steeles West, L'Amoreaux West
# Upper Rouge
# Hillcrest Village
# Fairview, Henry Farm, Oriole
# Bayview Village
# York Mills, Silver Hills
# Willowdale, Newtonbrook
# WillowdaleSouth
# York Mills West
# WillowdaleWest
# Parkwoods
# Don MillsNorth
# Don MillsSouth
# Bathurst Manor, Wilson Heights, Downsview North
# Northwood Park, York University
# DownsviewEast
# DownsviewWest
# DownsviewCentral
# DownsviewNorthwest
# Victoria Village
# Parkview Hill, Woodbine Gardens
# Woodbine Heights
# The Beaches
# Leaside
# Thorncliffe Park
# The Danforth  East
# The Danforth West, Riverdale
# India Bazaar, The Beaches West
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park, Summerhill East
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# Rosedale
# St. James Town, Cabbagetown
# Church and Wellesley
# Regent Park, Harbourfront
# Garden District, Ryerson
# St. James Town
# Berczy Park
# Central Bay Street
# Richmond, Adelaide, King
# Harbourfront East, Union Station, Toronto Islands
# Toronto Dominion Centre, Design Exchange
# Commerce Court, Victoria Hotel
# Bedford Park, Lawrence Manor East
# Roselawn
# Forest Hill North & West
# The Annex, North Midtown, Yorkville
# University of Toronto, Harbord
# Kensington Market, Chinatown, Grange Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Enclave of M5E
# First Canadian Place, Underground city
# Lawrence Manor, Lawrence Heights
# Glencairn
# Humewood-Cedarvale
# Caledonia-Fairbanks
# Christie
# Dufferin, Dovercourt Village
# Little Portugal, Trinity
# Brockton, Parkdale Village, Exhibition Place
# North Park, Maple Leaf Park, Upwood Park
# Del Ray, Mount Dennis, Keelsdale and Silverthorn
# Runnymede, The Junction North
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# None
# Enclave of L4W
# Enclave of M4L
# New Toronto, Mimico South, Humber Bay Shores
# Alderwood, Long Branch
# The Kingsway, Montgomery Road, Old Mill North
# Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East
# Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West
# Islington Avenue
# West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Humber Summit
# Humberlea, Emery
# Weston
# Westmount
# Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens
# South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens
# Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale

# %%
print('There are {} uniques categories.'.format(len(venues['Venue Category'].unique())))
# Out:
# There are 273 uniques categories.

# %% [markdown]
# ### One hot encoing of all venue categories, and insert Neighborhood name at the first column

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

print(toronto_onehot.shape)
# Out:
# (2226, 273)

# %% [markdown]
# ### To get the frequency of Neighborhood, proceed groupby and calculate mean data

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
print(toronto_grouped.shape)
# Out:
# (99, 273)

# %% [markdown]
# ### Create python function to sort the venues in descending order

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# ### create the new dataframe and display the top 10 venues for each neighborhood
# * Give number of top venues which want to get
# * set indicator for 1st, 2nd, 3rd, and so on
# * set column names with indicator and add string into the columns list
# * create new dataframe from grouped dataframe and new columns
# * slice dataframe into number of top venues

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                       Neighborhood 1st Most Common Venue  \
# 0                                       Agincourt           Skating Rink
# 1                           Alderwood, Long Branch           Pizza Place
# 2  Bathurst Manor, Wilson Heights, Downsview North                  Bank
# 3                                  Bayview Village    Chinese Restaurant
# 4                Bedford Park, Lawrence Manor East    Italian Restaurant
#
#        2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0  Latin American Restaurant        Clothing Store        Breakfast Spot
# 1               Skating Rink        Sandwich Place                  Pool
# 2                Coffee Shop   Fried Chicken Joint    Frozen Yogurt Shop
# 3                       Café   Japanese Restaurant                  Bank
# 4             Sandwich Place           Coffee Shop            Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0                Lounge               Dog Run          Dessert Shop
# 1              Pharmacy                   Pub                   Gym
# 2      Sushi Restaurant        Ice Cream Shop         Deli / Bodega
# 3         Women's Store    Dim Sum Restaurant                 Diner
# 4              Pharmacy             Juice Bar          Liquor Store
#
#   8th Most Common Venue 9th Most Common Venue     10th Most Common Venue
# 0    Dim Sum Restaurant                 Diner             Discount Store
# 1           Coffee Shop               Dog Run        Distribution Center
# 2           Pizza Place              Pharmacy  Middle Eastern Restaurant
# 3        Discount Store   Distribution Center                    Dog Run
# 4     Indian Restaurant        Ice Cream Shop       Fast Food Restaurant

# %% [markdown]
# ### Set the number of clusters, drop the unnecessary column, and fitting the data into K-means

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=26).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 0, 0, 3, 0, 0, 0, 0, 0, 1], dtype=int32)

# %% [markdown]
# ### insert the above label result into top number venue dataframe, and get the geolocation data from dfs

# %%
# incase reset cluster number above
# neighborhoods_venues_sorted.drop('Cluster Labels', axis=1, inplace=True)

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

dfs_merged = dfs_geo

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
dfs_merged = dfs_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
dfs_merged.head() # check the last columns!
# Out:
#   PostalCode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Malvern, Rouge  43.806686
# 1        M1C  Scarborough  Rouge Hill, Port Union, Highland Creek  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.194353             3.0  Fast Food Restaurant         Women's Store
# 1 -79.160497             2.0                   Bar         Women's Store
# 2 -79.188711             0.0     Electronics Store        Medical Center
# 3 -79.216917             0.0           Coffee Shop     Korean Restaurant
# 4 -79.239476             0.0   Fried Chicken Joint                Bakery
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0               Dog Run      Department Store          Dessert Shop
# 1          Dessert Shop    Dim Sum Restaurant                 Diner
# 2                   Spa    Mexican Restaurant          Intersection
# 3          Soccer Field      Doner Restaurant          Dessert Shop
# 4                  Bank    Athletics & Sports      Hakka Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0    Dim Sum Restaurant                 Diner        Discount Store
# 1        Discount Store   Distribution Center               Dog Run
# 2   Rental Car Location                  Bank                 Diner
# 3    Dim Sum Restaurant                 Diner        Discount Store
# 4  Caribbean Restaurant       Thai Restaurant           Gas Station
#
#   9th Most Common Venue 10th Most Common Venue
# 0   Distribution Center       Doner Restaurant
# 1      Doner Restaurant            Event Space
# 2      Department Store           Dessert Shop
# 3   Distribution Center                Dog Run
# 4        Discount Store           Dessert Shop

# %% [markdown]
# ### Removed NA value from the data frame, and reset the columns data type into integer

# %%
dfs_merged = dfs_merged[dfs_merged['Cluster Labels'].notna()]
dfs_merged['Cluster Labels'] = dfs_merged['Cluster Labels'].astype(int)

# %% [markdown]
# ### Same as above, visualized clusted data with folium

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))

rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(dfs_merged['Latitude'], dfs_merged['Longitude'], dfs_merged['Neighborhood'], dfs_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 1st Cluster - Date place near by

# %%
dfs_merged.loc[dfs_merged['Cluster Labels'] == 0, dfs_merged.columns[[1] + list(range(5, dfs_merged.shape[1]))]]
# Out:
#                                                Borough  Cluster Labels  \
# 2                                          Scarborough               0
# 3                                          Scarborough               0
# 4                                          Scarborough               0
# 5                                          Scarborough               0
# 6                                          Scarborough               0
# 7                                          Scarborough               0
# 8                                          Scarborough               0
# 9                                          Scarborough               0
# 10                                         Scarborough               0
# 11                                         Scarborough               0
# 12                                         Scarborough               0
# 14                                         Scarborough               0
# 17                                          North York               0
# 18                                          North York               0
# 20                                          North York               0
# 22                                          North York               0
# 26                                          North York               0
# 27                                          North York               0
# 28                                          North York               0
# 29                                          North York               0
# 31                                          North York               0
# 32                                          North York               0
# 33                                          North York               0
# 34                                          North York               0
# 36                                           East York               0
# 37                                        East Toronto               0
# 38                                           East York               0
# 39                                           East York               0
# 41                                        East Toronto               0
# 42                                        East Toronto               0
# ..                                                 ...             ...
# 61                                    Downtown Toronto               0
# 62                                          North York               0
# 63                                     Central Toronto               0
# 64                                     Central Toronto               0
# 65                                     Central Toronto               0
# 66                                    Downtown Toronto               0
# 67                                    Downtown Toronto               0
# 68                                    Downtown Toronto               0
# 69      Downtown TorontoStn A PO Boxes25 The Esplanade               0
# 70                                    Downtown Toronto               0
# 71                                          North York               0
# 72                                          North York               0
# 73                                                York               0
# 75                                    Downtown Toronto               0
# 76                                        West Toronto               0
# 77                                        West Toronto               0
# 78                                        West Toronto               0
# 81                                                York               0
# 82                                        West Toronto               0
# 83                                        West Toronto               0
# 84                                        West Toronto               0
# 86    MississaugaCanada Post Gateway Processing Centre               0
# 87   East TorontoBusiness reply mail Processing Cen...               0
# 88                                           Etobicoke               0
# 89                                           Etobicoke               0
# 91                                           Etobicoke               0
# 92                                           Etobicoke               0
# 95                                           Etobicoke               0
# 97                                          North York               0
# 102                                 EtobicokeNorthwest               0
#
#           1st Most Common Venue      2nd Most Common Venue  \
# 2             Electronics Store             Medical Center
# 3                   Coffee Shop          Korean Restaurant
# 4           Fried Chicken Joint                     Bakery
# 5    Construction & Landscaping                 Playground
# 6                Discount Store          Convenience Store
# 7                        Bakery                   Bus Line
# 8                  Skating Rink              Movie Theater
# 9                  Skating Rink            College Stadium
# 10            Indian Restaurant         Chinese Restaurant
# 11                   Smoke Shop                     Bakery
# 12                 Skating Rink  Latin American Restaurant
# 14                   Playground                Coffee Shop
# 17                  Golf Course   Mediterranean Restaurant
# 18               Clothing Store                Coffee Shop
# 20                    Cafeteria                    Dog Run
# 22             Ramen Restaurant                       Café
# 26                         Café             Baseball Field
# 27                   Beer Store                 Restaurant
# 28                         Bank                Coffee Shop
# 29               Massage Studio                Coffee Shop
# 31                Grocery Store                      Hotel
# 32                   Food Truck           Business Service
# 33           Athletics & Sports              Grocery Store
# 34                  Coffee Shop      Portuguese Restaurant
# 36                 Skating Rink             Cosmetics Shop
# 37                          Pub          Health Food Store
# 38          Sporting Goods Shop                Coffee Shop
# 39            Indian Restaurant                Yoga Studio
# 41             Greek Restaurant                Coffee Shop
# 42                   Board Shop          Fish & Chips Shop
# ..                          ...                        ...
# 61                  Coffee Shop                       Café
# 62           Italian Restaurant             Sandwich Place
# 63                       Garden              Women's Store
# 64                        Trail              Jewelry Store
# 65                         Café             Sandwich Place
# 66                         Café                 Restaurant
# 67                          Bar                       Café
# 68               Airport Lounge            Airport Service
# 69                  Coffee Shop                       Café
# 70                  Coffee Shop                       Café
# 71               Clothing Store          Accessories Store
# 72                          Pub                       Park
# 73                        Trail               Hockey Arena
# 75                Grocery Store                       Café
# 76                       Bakery                Pizza Place
# 77                          Bar                Coffee Shop
# 78               Breakfast Spot                Coffee Shop
# 81                Grocery Store                    Brewery
# 82              Thai Restaurant                        Bar
# 83                    Gift Shop                  Bookstore
# 84                         Café                Pizza Place
# 86                        Hotel                Coffee Shop
# 87                   Skate Park             Farmers Market
# 88           Seafood Restaurant        American Restaurant
# 89                  Pizza Place               Skating Rink
# 91               Baseball Field                  Locksmith
# 92            Convenience Store             Sandwich Place
# 95                         Café                Pizza Place
# 97               Baseball Field     Furniture / Home Store
# 102         Rental Car Location                  Drugstore
#
#       3rd Most Common Venue       4th Most Common Venue  \
# 2                       Spa          Mexican Restaurant
# 3              Soccer Field            Doner Restaurant
# 4                      Bank          Athletics & Sports
# 5                   Dog Run            Department Store
# 6                Hobby Shop            Department Store
# 7               Bus Station              Ice Cream Shop
# 8       American Restaurant                       Motel
# 9                      Café       General Entertainment
# 10    Vietnamese Restaurant                   Pet Store
# 11            Shopping Mall              Breakfast Spot
# 12           Clothing Store              Breakfast Spot
# 14                     Park                      Bakery
# 17                     Pool                     Dog Run
# 18     Fast Food Restaurant            Toy / Game Store
# 20         Department Store                Dessert Shop
# 22               Restaurant                 Pizza Place
# 26     Gym / Fitness Center        Caribbean Restaurant
# 27                      Gym            Asian Restaurant
# 28      Fried Chicken Joint          Frozen Yogurt Shop
# 29     Caribbean Restaurant                         Bar
# 31            Shopping Mall                        Park
# 32             Home Service              Baseball Field
# 33              Coffee Shop                Liquor Store
# 34             Hockey Arena  Financial or Legal Service
# 36              Curling Ice                  Beer Store
# 37                    Trail         Dumpling Restaurant
# 38   Furniture / Home Store                        Bank
# 39             Liquor Store                        Bank
# 41       Italian Restaurant                   Bookstore
# 42                     Park                   Pet Store
# ..                      ...                         ...
# 61               Restaurant                       Hotel
# 62              Coffee Shop                  Restaurant
# 63      Distribution Center            Department Store
# 64                     Park            Sushi Restaurant
# 65              Coffee Shop   Middle Eastern Restaurant
# 66                   Bakery                         Bar
# 67    Vietnamese Restaurant                 Coffee Shop
# 68            Boat or Ferry            Sculpture Garden
# 69       Seafood Restaurant                  Restaurant
# 70               Restaurant          Seafood Restaurant
# 71   Furniture / Home Store                  Shoe Store
# 72         Sushi Restaurant         Japanese Restaurant
# 73                    Field                  Playground
# 75                     Park                   Nightclub
# 76                 Pharmacy   Middle Eastern Restaurant
# 77         Asian Restaurant                  Restaurant
# 78                     Café                   Nightclub
# 81                 Bus Line           Convenience Store
# 82       Mexican Restaurant                        Café
# 83            Movie Theater                         Bar
# 84              Coffee Shop            Sushi Restaurant
# 86             Intersection               Burrito Place
# 87       Light Rail Station                     Brewery
# 88         Business Service                  Restaurant
# 89           Sandwich Place                        Pool
# 91         Doner Restaurant                Dessert Shop
# 92           Discount Store               Burrito Place
# 95               Beer Store                Liquor Store
# 97            Deli / Bodega                Dessert Shop
# 102     Distribution Center               Deli / Bodega
#
#              5th Most Common Venue        6th Most Common Venue  \
# 2                     Intersection          Rental Car Location
# 3                     Dessert Shop           Dim Sum Restaurant
# 4                 Hakka Restaurant         Caribbean Restaurant
# 5                     Dessert Shop           Dim Sum Restaurant
# 6                      Coffee Shop  Eastern European Restaurant
# 7                    Metro Station                 Soccer Field
# 8              Dumpling Restaurant                    Drugstore
# 9              Distribution Center             Department Store
# 10                   Women's Store             Department Store
# 11                  Sandwich Place                  Auto Garage
# 12                          Lounge                      Dog Run
# 14             Distribution Center             Department Store
# 17                  Discount Store             Department Store
# 18             Japanese Restaurant                    Juice Bar
# 20              Dim Sum Restaurant                        Diner
# 22                     Coffee Shop             Sushi Restaurant
# 26             Japanese Restaurant                 Dessert Shop
# 27                     Coffee Shop           Italian Restaurant
# 28                Sushi Restaurant               Ice Cream Shop
# 29                   Metro Station                Women's Store
# 31                            Bank          Distribution Center
# 32                Department Store                 Dessert Shop
# 33                         Dog Run                 Dessert Shop
# 34                   Women's Store               Discount Store
# 36                            Park                     Pharmacy
# 37                       Drugstore                   Donut Shop
# 38                    Burger Joint                Shopping Mall
# 39                     Pizza Place                     Pharmacy
# 41                  Ice Cream Shop       Furniture / Home Store
# 42                     Pizza Place                          Pub
# ..                             ...                          ...
# 61             American Restaurant                          Gym
# 62                        Pharmacy                    Juice Bar
# 63                    Dessert Shop           Dim Sum Restaurant
# 64             Distribution Center             Department Store
# 65                    Burger Joint            Indian Restaurant
# 66              Italian Restaurant                    Bookstore
# 67   Vegetarian / Vegan Restaurant                       Bakery
# 68                     Coffee Shop                          Bar
# 69                           Hotel                     Beer Bar
# 70                       Gastropub             Asian Restaurant
# 71                     Event Space        Vietnamese Restaurant
# 72                   Women's Store               Discount Store
# 73             Distribution Center             Department Store
# 75              Italian Restaurant                   Restaurant
# 76                     Supermarket                          Bar
# 77                     Men's Store                     Wine Bar
# 78                         Stadium                          Bar
# 81             Dumpling Restaurant                    Drugstore
# 82                           Diner                  Flea Market
# 83                Cuban Restaurant                      Dog Run
# 84              Italian Restaurant                  Yoga Studio
# 86                             Gym    Middle Eastern Restaurant
# 87                      Smoke Shop                   Comic Shop
# 88             Fried Chicken Joint                  Pizza Place
# 89                        Pharmacy                          Pub
# 91              Dim Sum Restaurant                        Diner
# 92                    Burger Joint         Fast Food Restaurant
# 95                  Cosmetics Shop            Convenience Store
# 97              Dim Sum Restaurant                        Diner
# 102               Department Store                 Dessert Shop
#
#      7th Most Common Venue        8th Most Common Venue  \
# 2                     Bank                        Diner
# 3                    Diner               Discount Store
# 4          Thai Restaurant                  Gas Station
# 5                    Diner               Discount Store
# 6      Dumpling Restaurant                    Drugstore
# 7                     Park                 Intersection
# 8               Donut Shop             Doner Restaurant
# 9             Dessert Shop           Dim Sum Restaurant
# 10            Dessert Shop           Dim Sum Restaurant
# 11            Concert Hall   Construction & Landscaping
# 12            Dessert Shop           Dim Sum Restaurant
# 14            Dessert Shop           Dim Sum Restaurant
# 17            Dessert Shop           Dim Sum Restaurant
# 18          Cosmetics Shop            Convenience Store
# 20          Discount Store          Distribution Center
# 22          Sandwich Place          Japanese Restaurant
# 26      Dim Sum Restaurant                        Diner
# 27          Discount Store                         Café
# 28           Deli / Bodega                  Pizza Place
# 29          Discount Store                 Dessert Shop
# 31        Department Store                 Dessert Shop
# 32      Dim Sum Restaurant                        Diner
# 33      Dim Sum Restaurant                        Diner
# 34        Department Store                 Dessert Shop
# 36           Women's Store                 Dessert Shop
# 37        Doner Restaurant                      Dog Run
# 38             Supermarket            Fish & Chips Shop
# 39    Fast Food Restaurant                   Restaurant
# 41      Frozen Yogurt Shop                          Pub
# 42            Liquor Store                Burrito Place
# ..                     ...                          ...
# 61      Italian Restaurant                Deli / Bodega
# 62            Liquor Store            Indian Restaurant
# 63                   Diner               Discount Store
# 64            Dessert Shop           Dim Sum Restaurant
# 65               BBQ Joint                   Donut Shop
# 66     Japanese Restaurant               Sandwich Place
# 67      Mexican Restaurant          Dumpling Restaurant
# 68        Airport Terminal              Harbor / Marina
# 69     Japanese Restaurant           Italian Restaurant
# 70                     Gym          American Restaurant
# 71             Coffee Shop                     Boutique
# 72        Department Store                 Dessert Shop
# 73            Dessert Shop           Dim Sum Restaurant
# 75             Candy Store                        Diner
# 76                    Pool                         Café
# 77   Vietnamese Restaurant                  Pizza Place
# 78                  Bakery                   Restaurant
# 81              Donut Shop  Eastern European Restaurant
# 82                  Bakery                    Speakeasy
# 83      Italian Restaurant                 Dessert Shop
# 84            Dessert Shop                    Bookstore
# 86          Sandwich Place          Fried Chicken Joint
# 87           Garden Center                       Garden
# 88                Pharmacy                    Pet Store
# 89                     Gym                  Coffee Shop
# 91          Discount Store          Distribution Center
# 92         Supplement Shop               Hardware Store
# 95          Shopping Plaza                         Park
# 97          Discount Store          Distribution Center
# 102     Dim Sum Restaurant                        Diner
#
#            9th Most Common Venue       10th Most Common Venue
# 2               Department Store                 Dessert Shop
# 3            Distribution Center                      Dog Run
# 4                 Discount Store                 Dessert Shop
# 5            Distribution Center                Women's Store
# 6                     Donut Shop             Doner Restaurant
# 7                 Discount Store           Dim Sum Restaurant
# 8    Eastern European Restaurant                 Dance Studio
# 9                          Diner               Discount Store
# 10                         Diner               Discount Store
# 11               College Stadium  Eastern European Restaurant
# 12                         Diner               Discount Store
# 14                         Diner               Discount Store
# 17                         Diner          Distribution Center
# 18                 Women's Store                         Bank
# 20                 Women's Store                Deli / Bodega
# 22                 Shopping Mall              Bubble Tea Shop
# 26                Discount Store          Distribution Center
# 27           Sporting Goods Shop           Chinese Restaurant
# 28                      Pharmacy    Middle Eastern Restaurant
# 29            Dim Sum Restaurant                        Diner
# 31            Dim Sum Restaurant                        Diner
# 32                Discount Store                Women's Store
# 33                Discount Store          Distribution Center
# 34            Dim Sum Restaurant                        Diner
# 36            Dim Sum Restaurant                        Diner
# 37           Distribution Center                  Curling Ice
# 38              Department Store                 Liquor Store
# 39                          Park                 Burger Joint
# 41                   Pizza Place                 Liquor Store
# 42                    Restaurant                      Brewery
# ..                           ...                          ...
# 61           Japanese Restaurant                    Gastropub
# 62                Ice Cream Shop         Fast Food Restaurant
# 63                       Dog Run                 Dance Studio
# 64                         Diner               Discount Store
# 65                  Liquor Store               History Museum
# 66                          Bank                     Beer Bar
# 67                Farmers Market                Grocery Store
# 68                  Airport Gate                      Airport
# 69                           Gym                          Pub
# 70                    Steakhouse                        Hotel
# 71            Miscellaneous Shop                Women's Store
# 72            Dim Sum Restaurant                        Diner
# 73                         Diner               Discount Store
# 75                    Baby Store                  Gas Station
# 76          Fast Food Restaurant                         Bank
# 77                          Café             Greek Restaurant
# 78                  Intersection           Italian Restaurant
# 81              Department Store             Doner Restaurant
# 82          Fast Food Restaurant          Arts & Crafts Store
# 83                    Restaurant                  Coffee Shop
# 84                Sandwich Place                   Restaurant
# 86           American Restaurant     Mediterranean Restaurant
# 87                 Burrito Place                         Park
# 88                        Bakery         Fast Food Restaurant
# 89                       Dog Run          Distribution Center
# 91                       Dog Run                Women's Store
# 92                        Bakery                   Kids Store
# 95                   Coffee Shop                   Comic Shop
# 97                       Dog Run                Women's Store
# 102               Discount Store                      Dog Run
#
# [77 rows x 12 columns]

# %% [markdown]
# ## 2nd Cluster - Park near by

# %%
dfs_merged.loc[dfs_merged['Cluster Labels'] == 1, dfs_merged.columns[[1] + list(range(5, dfs_merged.shape[1]))]]
# Out:
#                    Borough  Cluster Labels       1st Most Common Venue  \
# 23              North York               1                        Park
# 25              North York               1                        Park
# 30              North York               1                        Park
# 40   East YorkEast Toronto               1                        Park
# 50        Downtown Toronto               1                        Park
# 74                    York               1                        Park
# 79              North York               1  Construction & Landscaping
# 90               Etobicoke               1                       River
# 100              Etobicoke               1                        Park
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 23      Convenience Store                  Bank         Women's Store
# 25      Food & Drink Shop         Women's Store   Distribution Center
# 30                Airport         Women's Store               Dog Run
# 40          Metro Station     Convenience Store         Deli / Bodega
# 50                  Trail            Playground          Dance Studio
# 74          Women's Store                Market   Distribution Center
# 79                   Park                Bakery               Dog Run
# 90                   Park         Women's Store   Distribution Center
# 100           Pizza Place        Sandwich Place         Women's Store
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 23           Dessert Shop    Dim Sum Restaurant                 Diner
# 25       Department Store          Dessert Shop    Dim Sum Restaurant
# 30       Department Store          Dessert Shop    Dim Sum Restaurant
# 40       Department Store          Dessert Shop    Dim Sum Restaurant
# 50          Deli / Bodega      Department Store          Dessert Shop
# 74       Department Store          Dessert Shop    Dim Sum Restaurant
# 79           Dessert Shop    Dim Sum Restaurant                 Diner
# 90       Department Store          Dessert Shop    Dim Sum Restaurant
# 100        Discount Store         Deli / Bodega      Department Store
#
#     8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 23         Discount Store   Distribution Center                Dog Run
# 25                  Diner        Discount Store                Dog Run
# 30                  Diner        Discount Store    Distribution Center
# 40                  Diner        Discount Store          Women's Store
# 50     Dim Sum Restaurant                 Diner         Discount Store
# 74                  Diner        Discount Store                Dog Run
# 79         Discount Store   Distribution Center          Women's Store
# 90                  Diner        Discount Store                Dog Run
# 100          Dessert Shop    Dim Sum Restaurant                  Diner

# %% [markdown]
# ## 3rd Cluster - Bar near by

# %%
dfs_merged.loc[dfs_merged['Cluster Labels'] == 2, dfs_merged.columns[[1] + list(range(5, dfs_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 1  Scarborough               2                   Bar         Women's Store
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 1          Dessert Shop    Dim Sum Restaurant                 Diner
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 1        Discount Store   Distribution Center               Dog Run
#
#   9th Most Common Venue 10th Most Common Venue
# 1      Doner Restaurant            Event Space

# %% [markdown]
# ## 4th Cluster - Restaurant near by

# %%
dfs_merged.loc[dfs_merged['Cluster Labels'] == 3, dfs_merged.columns[[1] + list(range(5, dfs_merged.shape[1]))]]
# Out:
#          Borough  Cluster Labels 1st Most Common Venue  \
# 0    Scarborough               3  Fast Food Restaurant
# 13   Scarborough               3           Pizza Place
# 15   Scarborough               3  Fast Food Restaurant
# 19    North York               3    Chinese Restaurant
# 24    North York               3           Pizza Place
# 35     East York               3           Pizza Place
# 80          York               3          Skating Rink
# 96    North York               3   Empanada Restaurant
# 98          York               3     Convenience Store
# 99     Etobicoke               3           Pizza Place
# 101    Etobicoke               3         Grocery Store
#
#          2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                Women's Store               Dog Run      Department Store
# 13                Noodle House              Pharmacy    Italian Restaurant
# 15          Chinese Restaurant              Pharmacy            Nail Salon
# 19                        Café   Japanese Restaurant                  Bank
# 24               Grocery Store                  Bank           Coffee Shop
# 35                    Pharmacy          Intersection        Breakfast Spot
# 80        Fast Food Restaurant        Discount Store        Sandwich Place
# 96               Shopping Mall           Pizza Place   Distribution Center
# 98               Women's Store          Dessert Shop    Dim Sum Restaurant
# 99   Middle Eastern Restaurant        Discount Store           Coffee Shop
# 101                Pizza Place        Discount Store            Beer Store
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0            Dessert Shop    Dim Sum Restaurant                 Diner
# 13           Intersection  Fast Food Restaurant                  Bank
# 15          Grocery Store                  Bank           Coffee Shop
# 19          Women's Store    Dim Sum Restaurant                 Diner
# 24           Home Service              Pharmacy        Discount Store
# 35                   Bank  Gym / Fitness Center  Fast Food Restaurant
# 80                Dog Run          Dessert Shop    Dim Sum Restaurant
# 96          Deli / Bodega      Department Store          Dessert Shop
# 98                  Diner        Discount Store   Distribution Center
# 99         Sandwich Place    Chinese Restaurant         Deli / Bodega
# 101        Sandwich Place              Pharmacy   Fried Chicken Joint
#
#     8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0          Discount Store   Distribution Center       Doner Restaurant
# 13      Convenience Store    Chinese Restaurant        Thai Restaurant
# 15         Breakfast Spot        Sandwich Place            Pizza Place
# 19         Discount Store   Distribution Center                Dog Run
# 24    Distribution Center      Department Store           Dessert Shop
# 35              Gastropub    Athletics & Sports                   Café
# 80                  Diner   Distribution Center       Doner Restaurant
# 96     Dim Sum Restaurant                 Diner         Discount Store
# 98                Dog Run      Doner Restaurant          Deli / Bodega
# 99       Department Store          Dessert Shop     Dim Sum Restaurant
# 101   Japanese Restaurant  Fast Food Restaurant       Department Store

# %% [markdown]
# ## 5th Gift Shop

# %%
dfs_merged.loc[dfs_merged['Cluster Labels'] == 4, dfs_merged.columns[[1] + list(range(5, dfs_merged.shape[1]))]]
# Out:
#       Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 94  Etobicoke               4             Gift Shop         Women's Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 94               Dog Run      Department Store          Dessert Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 94    Dim Sum Restaurant                 Diner        Discount Store
#
#    9th Most Common Venue 10th Most Common Venue
# 94   Distribution Center       Doner Restaurant
